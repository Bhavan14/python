# %% [markdown]
# ***Import libraries***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Titanic.csv')
df
# Out:
#      Column1  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0          0         0       3    male  22.0      1      0   7.2500        S
# 1          1         1       1  female  38.0      1      0  71.2833        C
# 2          2         1       3  female  26.0      0      0   7.9250        S
# 3          3         1       1  female  35.0      1      0  53.1000        S
# 4          4         0       3    male  35.0      0      0   8.0500        S
# ..       ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886      886         0       2    male  27.0      0      0  13.0000        S
# 887      887         1       1  female  19.0      0      0  30.0000        S
# 888      888         0       3  female   NaN      1      2  23.4500        S
# 889      889         1       1    male  26.0      0      0  30.0000        C
# 890      890         0       3    male  32.0      0      0   7.7500        Q
#
# ...

# %%
len(df)
# Out:
# 891

# %%
df.shape
# Out:
# (891, 16)

# %%
df.isnull().sum()
# Out:
# Column1          0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['deck'].isnull().sum()/len(df)
# Out:
# np.float64(0.7721661054994389)

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df.drop(columns=['deck'],inplace=True)

# %%
df
# Out:
#      Column1  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0          0         0       3    male  22.0      1      0   7.2500        S
# 1          1         1       1  female  38.0      1      0  71.2833        C
# 2          2         1       3  female  26.0      0      0   7.9250        S
# 3          3         1       1  female  35.0      1      0  53.1000        S
# 4          4         0       3    male  35.0      0      0   8.0500        S
# ..       ...       ...     ...     ...   ...    ...    ...      ...      ...
# 886      886         0       2    male  27.0      0      0  13.0000        S
# 887      887         1       1  female  19.0      0      0  30.0000        S
# 888      888         0       3  female   NaN      1      2  23.4500        S
# 889      889         1       1    male  26.0      0      0  30.0000        C
# 890      890         0       3    male  32.0      0      0   7.7500        Q
#
# ...

# %%
df.isnull().sum()
# Out:
# Column1          0
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].mean(),inplace=True)
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Column1        0
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       0
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
df
# Out:
#      Column1  survived  pclass     sex        age  sibsp  parch     fare  \
# 0          0         0       3    male  22.000000      1      0   7.2500
# 1          1         1       1  female  38.000000      1      0  71.2833
# 2          2         1       3  female  26.000000      0      0   7.9250
# 3          3         1       1  female  35.000000      1      0  53.1000
# 4          4         0       3    male  35.000000      0      0   8.0500
# ..       ...       ...     ...     ...        ...    ...    ...      ...
# 886      886         0       2    male  27.000000      0      0  13.0000
# 887      887         1       1  female  19.000000      0      0  30.0000
# 888      888         0       3  female  29.699118      1      2  23.4500
# 889      889         1       1    male  26.000000      0      0  30.0000
# 890      890         0       3    male  32.000000      0      0   7.7500
#
#     embarked   class    who  adult_male  embark_town alive  alone
# ...

# %%
df['sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df['sex'].value_counts()
# Out:
# sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df['embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
df['class'].unique()
# Out:
# array(['Third', 'First', 'Second'], dtype=object)

# %%
df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
df["embark_town"].unique()
# Out:
# array(['Southampton', 'Cherbourg', 'Queenstown'], dtype=object)

# %%
df['class']=df['class'].map({'First':1,'Second':2,'Third':3})

# %%
df['sex']=df['sex'].map({'male':1,'female':0})

# %%
df['who']=df['who'].map({'man':1,'woman':2,'child':3})

# %%
df['embarked']=df['embarked'].map({'S':1,'C':2,'Q':3})

# %%
df['adult_male']=df['adult_male'].map({True:1,False:0})

# %%
df['embark_town']=df['embark_town'].map({'Southampton':1,'Cherbourg':2,'Queenstown':3})

# %%
df['alive']=df['alive'].map({'yes':1,'no':0})

# %%
df['alone']=df['alone'].map({True:1,False:0})

# %%
df
# Out:
#      Column1  survived  pclass  sex        age  sibsp  parch     fare  \
# 0          0         0       3    1  22.000000      1      0   7.2500
# 1          1         1       1    0  38.000000      1      0  71.2833
# 2          2         1       3    0  26.000000      0      0   7.9250
# 3          3         1       1    0  35.000000      1      0  53.1000
# 4          4         0       3    1  35.000000      0      0   8.0500
# ..       ...       ...     ...  ...        ...    ...    ...      ...
# 886      886         0       2    1  27.000000      0      0  13.0000
# 887      887         1       1    0  19.000000      0      0  30.0000
# 888      888         0       3    0  29.699118      1      2  23.4500
# 889      889         1       1    1  26.000000      0      0  30.0000
# 890      890         0       3    1  32.000000      0      0   7.7500
#
#      embarked  class  who  adult_male  embark_town  alive  alone
# ...

# %%
df['age']=df['age'].astype(int)

# %%
df['fare']=df['fare'].astype(int)

# %%
df
# Out:
#      Column1  survived  pclass  sex  age  sibsp  parch  fare  embarked  class  \
# 0          0         0       3    1   22      1      0     7         1      3
# 1          1         1       1    0   38      1      0    71         2      1
# 2          2         1       3    0   26      0      0     7         1      3
# 3          3         1       1    0   35      1      0    53         1      1
# 4          4         0       3    1   35      0      0     8         1      3
# ..       ...       ...     ...  ...  ...    ...    ...   ...       ...    ...
# 886      886         0       2    1   27      0      0    13         1      2
# 887      887         1       1    0   19      0      0    30         1      1
# 888      888         0       3    0   29      1      2    23         1      3
# 889      889         1       1    1   26      0      0    30         2      1
# 890      890         0       3    1   32      0      0     7         3      3
#
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',annot_kws={'fontsize':8})
#
# Out:
# <Axes: >

# %%
plt.scatter(df['survived'],df['embark_town'])
#

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
df_stand=pd.DataFrame(ss.fit_transform(df),columns=df.columns)

# %%
df_stand.boxplot(figsize=(20,10))
plt.show()

# %%
q1=df['age'].quantile(0.25)
q1
# Out:
# np.float64(22.0)

# %%
q3=df['age'].quantile(0.75)
q3
# Out:
# np.float64(35.0)

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(13.0)

# %%
LL=q1-1.5*IQR
LL
# Out:
# np.float64(2.5)

# %%
Ul=q3+1.5*IQR
Ul
# Out:
# np.float64(54.5)

# %%
df['age']=df['age'][(df['age']>LL)&(df['age']<Ul)]
df['age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    29.0
# 889    26.0
# 890    32.0
# Name: age, Length: 891, dtype: float64

# %%
df['age'].isnull().sum()
# Out:
# np.int64(66)

# %%
df['age'].fillna(df['age'].mean(),inplace=True)

# %%
df['age'].isnull().sum()
# Out:
# np.int64(0)

# %%
q1=df['fare'].quantile(0.25)
q1
# Out:
# np.float64(7.0)

# %%
q3=df['fare'].quantile(0.75)
q3
# Out:
# np.float64(31.0)

# %%
IQR=q3-q1
IQR
# Out:
# np.float64(24.0)

# %%
LL=q1-1.5*IQR
LL
# Out:
# np.float64(-29.0)

# %%
UP=q3+1.5*IQR
UP
# Out:
# np.float64(67.0)

# %%
df['fare']=df['fare'][(df['fare']>LL)&(df['fare']<UP)]
df['fare']
# Out:
# 0       7.0
# 1       NaN
# 2       7.0
# 3      53.0
# 4       8.0
#        ...
# 886    13.0
# 887    30.0
# 888    23.0
# 889    30.0
# 890     7.0
# Name: fare, Length: 891, dtype: float64

# %%
df['fare'].isnull().sum()
# Out:
# np.int64(114)

# %%
df['fare'].fillna(df['fare'].mean(),inplace=True)

# %%
df['fare'].isnull().sum()
# Out:
# np.int64(0)

# %%
counts=df.groupby(['sex','alive']).size().unstack()
counts.plot(kind='bar',figsize=(10,10))
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Alive vs Death Count')
plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['pclass','sex','age','sibsp','parch','fare','embarked']]
x
# Out:
#      pclass  sex   age  sibsp  parch       fare  embarked
# 0         3    1  22.0      1      0   7.000000         1
# 1         1    0  38.0      1      0  17.530245         2
# 2         3    0  26.0      0      0   7.000000         1
# 3         1    0  35.0      1      0  53.000000         1
# 4         3    1  35.0      0      0   8.000000         1
# ..      ...  ...   ...    ...    ...        ...       ...
# 886       2    1  27.0      0      0  13.000000         1
# 887       1    0  19.0      0      0  30.000000         1
# 888       3    0  29.0      1      2  23.000000         1
# 889       1    1  26.0      0      0  30.000000         2
# 890       3    1  32.0      0      0   7.000000         3
#
# [891 rows x 7 columns]

# %%
y=df['survived']
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: survived, Length: 891, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
len(x_train)
# Out:
# 712

# %%
len(x_test)
# Out:
# 179

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_predict=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# ***RESULT:***

# %%
lr_score=accuracy_score(y_test,y_predict)*100
lr_score
# Out:
# 77.09497206703911

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_predict))
# Out:
# [[85 20]
#  [21 53]]
